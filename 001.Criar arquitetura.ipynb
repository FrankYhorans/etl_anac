# %%
# criar arquitetura oficial
spark.sql("CREATE CATALOG IF NOT EXISTS anac") 
spark.sql("CREATE SCHEMA IF NOT EXISTS anac.databricks")


spark.sql("""
CREATE VOLUME IF NOT EXISTS anac.databricks.anac_volume
""")
